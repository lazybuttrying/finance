# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-darkgrid')
pd.set_option('display.float_format', lambda x: '%.6f' % x)

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['axes.titlepad'] = 20

# pd.set_option('display.float_format', lambda x: '%.6f' % x)

df = pd.read_csv('summary_stat_delta_cashflow.csv')
df = df[~df["ind_code"].isna()]
# Out:
# C:\Users\DYK\AppData\Local\Temp\ipykernel_21524\2416222339.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
df.head()
# Out:
#          date firmcode    depre         age    n_acq_intangi  \
# 0  2000-03-31  A000020 0.000000  1897-09-25 128058000.000000
# 1  2000-06-30  A000020 0.000000  1897-09-25  68893000.000000
# 2  2000-09-30  A000020 0.000000  1897-09-25  68893000.000000
# 3  2000-12-31  A000020 0.000000  1897-09-25  68893000.000000
# 4  2001-03-31  A000020 0.000000  1897-09-25  68893000.000000
#
#                tangi          intangi               cash             payab  \
# 0 50412797000.000000 292445000.000000  8635459000.000000 5895454000.000000
# 1 49777695000.000000 323662000.000000  4334065000.000000 6857519000.000000
# 2 49823748000.000000 336121000.000000  5804901000.000000 7777695000.000000
# 3 49411447000.000000 318558000.000000 10400728000.000000 7745139000.000000
# 4 48119915000.000000 324531000.000000 15199388000.000000 5131608000.000000
#
#               invent  ...  cashflow_q1_mean  cashflow_q1_cnt  \
# 0 17458995000.000000  ...          0.003015                2
# ...

# %% [markdown]
# # With NaN industry code

# %%
df.describe().T
# Out:
#                          count                 mean                   std  \
# depre            179201.000000    6172720598.975061    83876648301.925613
# n_acq_intangi    201273.000000    3095026243.697814    43101856808.413422
# tangi            172240.000000  222927321864.450165  1832725277885.563965
# intangi          172240.000000   20195127018.400703   192673680102.815125
# cash             172240.000000   34595396033.897163   176149998177.563171
# payab            172240.000000   46667959995.663605   285641443193.518372
# invent           172240.000000   50085983340.033943   353555997602.750427
# receiv           170843.000000   82862274484.451202   562150599826.963379
# st_debt          172240.000000   75405653167.382706   334773491010.616943
# lt_debt          172240.000000   85173434193.781601   540983794812.072388
# t_debt           172240.000000  313764301280.863708  1593893987704.717773
# amort            179642.000000     707752421.952272    11076475060.475485
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 305415 entries, 0 to 317789
# Data columns (total 59 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              305415 non-null  object
#  1   firmcode          305415 non-null  object
#  2   depre             179201 non-null  float64
#  3   age               305415 non-null  object
#  4   n_acq_intangi     201273 non-null  float64
#  5   tangi             172240 non-null  float64
#  6   intangi           172240 non-null  float64
#  7   cash              172240 non-null  float64
#  8   payab             172240 non-null  float64
#  9   invent            172240 non-null  float64
#  10  receiv            170843 non-null  float64
#  11  st_debt           172240 non-null  float64
#  12  lt_debt           172240 non-null  float64
#  13  t_debt            172240 non-null  float64
#  14  amort             179642 non-null  float64
# ...

# %%
df["ind_code"].value_counts(dropna=False)
# Out:
# ind_code
# C    201663
# J     40689
# G     23562
# M     19503
# F      9900
# H      2970
# N      2376
# P      1287
# R      1287
# I       693
# L       594
# A       594
# B       198
# S        99
# Name: count, dtype: int64

# %%
df["ind_code"].value_counts(dropna=False).to_frame().sort_index().plot(
    kind='bar', figsize=(10,5), title='산업별 Frequency',
    xlabel='산업코드', ylabel='Frequency'
)
# Out:
# <Axes: title={'center': '산업별 Frequency'}, xlabel='산업코드', ylabel='Frequency'>

# %%
df["exchange"].value_counts(dropna=False).to_frame()
# Out:
#            count
# exchange
# NaN       120521
# 코스닥       116957
# 유가증권시장     66403
# KONEX       1002
# 비상장          497
# K-OTC         35

# %%
df[['ind_code', 'exchange']].groupby(['ind_code', 'exchange', ]).size().to_frame().plot(
    kind='bar', figsize=(15,5), title='산업별 거래소별 Frequency',
    xlabel='산업코드, 거래소', ylabel='Frequency', legend=False,
    rot=80, grid=True
)
# Out:
# <Axes: title={'center': '산업별 거래소별 Frequency'}, xlabel='산업코드, 거래소', ylabel='Frequency'>

# %%
df[['exchange', 'main_quater']].groupby(['exchange', 'main_quater', ]).size().to_frame().plot(
    kind='bar', figsize=(15,4), title='거래소별 Main Quater별 Frequency',
    xlabel='거래소, Main Quater', ylabel='Frequency',
    rot=80
)
# Out:
# <Axes: title={'center': '거래소별 Main Quater별 Frequency'}, xlabel='거래소, Main Quater', ylabel='Frequency'>

# %%
df[['ind_code', 'main_quater']].groupby(['ind_code', 'main_quater', ]).size().to_frame().plot(
    kind='bar', figsize=(20,5), title='산업별 Main Quater별 Frequency',
    xlabel='산업코드, Main Quater', ylabel='Frequency',
    rot=80
)
# Out:
# <Axes: title={'center': '산업별 Main Quater별 Frequency'}, xlabel='산업코드, Main Quater', ylabel='Frequency'>

# %%
print(df[df["cashflow"]>0].shape[0] / df.shape[0] * 100)

print(df.shape)
df[df["cashflow"] <= -0.5].shape, df[df["cashflow"] >= 0.5].shape
# Out:
# 40.511435260219706
# (305415, 59)
# ((77, 59), (60, 59))

# %%
# 이상치 제거 후
df[(df["cashflow"]> -1) & (df["cashflow"]<1)]["cashflow"].plot(
    kind='hist', bins=500, figsize=(15,5), title='Cashflow Distribution After Removing Outliers',
    xlabel='Cashflow', ylabel='Frequency'
)
# Out:
# <Axes: title={'center': 'Cashflow Distribution After Removing Outliers'}, xlabel='Cashflow', ylabel='Frequency'>

# %% [markdown]
# # With Existance of Main Quater

# %%
df = df[(df["main_quater_cnt"]==True)]

# %%
df["ind_code"].value_counts(dropna=False).to_frame().sort_index().plot(
    kind='bar', figsize=(10,5), title='산업별 Frequency',
    xlabel='산업코드', ylabel='Frequency'
)
# Out:
# <Axes: title={'center': '산업별 Frequency'}, xlabel='산업코드', ylabel='Frequency'>

# %%
df["exchange"].value_counts(dropna=False).to_frame()
# Out:
#           count
# exchange
# NaN       14492
# 코스닥       11717
# 유가증권시장     8433
# KONEX       207
# 비상장         141

# %%
df[['ind_code', 'exchange']].groupby(['ind_code', 'exchange', ]).size().to_frame().plot(
    kind='bar', figsize=(15,5), title='산업별 거래소별 Frequency',
    xlabel='산업코드, 거래소', ylabel='Frequency', legend=False,
    rot=80, grid=True
)
# Out:
# <Axes: title={'center': '산업별 거래소별 Frequency'}, xlabel='산업코드, 거래소', ylabel='Frequency'>

# %%
df[['exchange', 'main_quater']].groupby(['exchange', 'main_quater', ]).size().to_frame().plot(
    kind='bar', figsize=(15,4), title='거래소별 Main Quater별 Frequency',
    xlabel='거래소, Main Quater', ylabel='Frequency',
    rot=80
)
# Out:
# <Axes: title={'center': '거래소별 Main Quater별 Frequency'}, xlabel='거래소, Main Quater', ylabel='Frequency'>

# %%
df[['ind_code', 'main_quater']].groupby(['ind_code', 'main_quater', ]).size().to_frame().plot(
    kind='bar', figsize=(20,5), title='산업별 Main Quater별 Frequency',
    xlabel='산업코드, Main Quater', ylabel='Frequency',
    rot=80
)
# Out:
# <Axes: title={'center': '산업별 Main Quater별 Frequency'}, xlabel='산업코드, Main Quater', ylabel='Frequency'>

# %%
print(df[df["cashflow"]>0].shape[0] / df.shape[0] * 100)

print(df.shape)
df[df["cashflow"] <= -0.5].shape, df[df["cashflow"] >= 0.5].shape
# Out:
# 52.57216347527866
# (34990, 59)
# ((6, 59), (8, 59))

# %%
# 이상치 제거 후
df[(df["cashflow"]> -1) & (df["cashflow"]<1)]["cashflow"].plot(
    kind='hist', bins=500, figsize=(15,5), title='Cashflow Distribution After Removing Outliers',
    xlabel='Cashflow', ylabel='Frequency'
)
# Out:
# <Axes: title={'center': 'Cashflow Distribution After Removing Outliers'}, xlabel='Cashflow', ylabel='Frequency'>
